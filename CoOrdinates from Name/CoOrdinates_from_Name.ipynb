# %%
import ee
import geemap
import logging
import multiprocessing
import os
import requests
import shutil
from retry import retry

# %%
ee.Authenticate()
ee.Initialize()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=way3W3hKLPkRbElzJl9z7ehl0PY1DLYveoXS0kRh31A&tc=SuurvnLF-PXeVfkLBrkap1EbSUFjv27TLC4YPLE9PA8&cc=f3Iy2cH47bg_t94AFq5RuDlcwlK-A5sLPXwCLc-SUyo>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=way3W3hKLPkRbElzJl9z7ehl0PY1DLYveoXS0kRh31A&tc=SuurvnLF-PXeVfkLBrkap1EbSUFjv27TLC4YPLE9PA8&cc=f3Iy2cH47bg_t94AFq5RuDlcwlK-A5sLPXwCLc-SUyo</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Enter verification code: 4/1AbUR2VPmh-c76JLYt-kZ486AlvDM8MDXKLC8O5owRDGWnQOHdP8fphVI-y4
#
# Successfully saved authorization token.

# %%
ee.Initialize(opt_url='https://earthengine-highvolume.googleapis.com')

# %%
Map = geemap.Map()
Map
# Out:
# Map(center=[20, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(Togg…
# could not convert string to float: ''
# could not convert string to float: ''
# The lat-lon coordinates should be numbers only and separated by comma or space, such as 40.2, -100.3

# %%
ds = ee.FeatureCollection("projects/ee-pnolaraj/assets/Ktm_Shp")
Map.addLayer(ds, {}, "Kathmandu")

# %%
# Provide any string on the name for filtering
def School_CoOrdinates(String):
    filtered_features = ds.filter(ee.Filter.stringContains('name', String))

    # Map over the filtered features to extract their coordinates
    coordinates_list = filtered_features.geometry().coordinates()

    # Print the list of coordinates
    print(f'Coordinates for {String}:')
    CoOrdinatesList = coordinates_list.getInfo()
    return CoOrdinatesList

# %%
print(School_CoOrdinates(String = "College"))
# Out:
# Coordinates for College:
# [[[[85.33665728217186, 27.695293831527337], [85.33706305604218, 27.695173416968593], [85.33714332731314, 27.69539194249258], [85.33673755403971, 27.695507892238773], [85.33665728217186, 27.695293831527337]]], [[[85.28939531959107, 27.6885650105855], [85.2900284973215, 27.688386631724953], [85.29025144548413, 27.68872556763123], [85.29033612608825, 27.68919375969961], [85.28976987631589, 27.689416733976454], [85.28939531959107, 27.6885650105855]]], [[[85.3479075967276, 27.68654509430485], [85.34792549256885, 27.686406828373052], [85.34824201936306, 27.68644698426039], [85.34820638555423, 27.686607517802855], [85.3479075967276, 27.68654509430485]]], [[[85.34293130010165, 27.67358242922443], [85.34298925005268, 27.67352891056769], [85.34306951260427, 27.67360474298659], [85.34300706866472, 27.673653824303138], [85.34293130010165, 27.67358242922443]]], [[[85.30213496543621, 27.687918448537463], [85.3022865367623, 27.687873834594253], [85.30233561390543, 27.68807453817045], [85.3021750478475, 27.68810125636211], [85.30213496543621, 27.687918448537463]]], [[[85.36